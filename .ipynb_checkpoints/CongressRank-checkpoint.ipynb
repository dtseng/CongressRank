# %%
import os
import requests
import random
import pickle
KEY = '91mTqXFEeSaCIbjC0fuaB1RABk4HANqS4I91qRBN'
KEY2 = 'flLQZGa0kx8opciUA6M7R9iLPwfFPj5yFKKlCiVb'

MOST_RECENT_HR_BILL = 6536 #1490
MOST_RECENT_S_BILL = 3548  #606
CONGRESS = 114

# %%
import re 
from lxml import html
temp = set()
page = requests.get('https://www.congress.gov/search?q={%22type%22:%22bills%22,%22source%22:%22legislation%22,%22congress%22:%22114%22,%22bill-status%22:%22passed-one%22,%22chamber%22:%22Senate%22}&pageSize=250&page=1')
tree = html.fromstring(page.content)
bills = tree.xpath('//span[@class="result-heading"]//a/text()')
temp |= set(bills)

senate_passed_one_house = set()
for bill in temp:
    senate_passed_one_house.add(int(''.join(list(filter(str.isdigit, bill)))))

    

temp = set()    
for i in range(1, 10):
    page = requests.get('https://www.congress.gov/search?pageSort=documentNumber:asc&q={%22congress%22:%22114%22,%22type%22:%22bills%22,%22bill-status%22:[%22passed-one%22],%22chamber%22:%22House%22}&pageSize=250&page=' + str(i))
    tree = html.fromstring(page.content)
    bills = tree.xpath('//span[@class="result-heading"]//a/text()')
    temp |= set(bills)
    
hr_passed_one_house = set()
for bill in temp:
    hr_passed_one_house.add(int(''.join(list(filter(str.isdigit, bill)))))

# %%
def getJSON(webpage):
    headers = {
        'X-API-Key': KEY
    }
    r = requests.get(webpage, headers=headers)
    return r.json()

def getSponsors(bill_id, congress, progress = 'introduced'):
    '''Returns (PrimarySponsor, [cosponsors]) for specified bill_id and congress strings. Returns () if faulty'''
    '''progress = 'introduced', 'became law'                                                                '''
    edge = getJSON('https://api.propublica.org/congress/v1/' + str(congress) + '/bills/' + bill_id + '/cosponsors.json')
    toReturn = False
    if edge['status'] == 'OK':
        if progress =='introduced':
            toReturn = True
        elif progress == 'became law':
            toReturn = edge['results'][0]['latest_major_action'][:17] == 'Became Public Law'           
                
    if toReturn:
        return (edge['results'][0]['sponsor_id'], [cosponsor['cosponsor_id'] for cosponsor in edge['results'][0]['cosponsors']])
    else:
        return ()
    
def getMembers(congress):
    '''takes congress session and Returns dictioanry of congress member ids with value 0'''
    senate_members = getJSON('https://api.propublica.org/congress/v1/'+ str(congress) +'/senate/members.json')
    house_members = getJSON('https://api.propublica.org/congress/v1/'+ str(congress) +'/house/members.json')
    senateList, houseList = [],[]
    if senate_members['status'] == 'OK':
        senateList = [(senator['id'],0) for senator in senate_members['results'][0]['members']]
    if house_members['status'] == 'OK':
        houseList = [(rep['id'],0) for rep in house_members['results'][0]['members']]
    return dict(senateList + houseList)

def getNameIDPairing(congress):
    senate_members = getJSON('https://api.propublica.org/congress/v1/'+ str(congress) +'/senate/members.json')
    house_members = getJSON('https://api.propublica.org/congress/v1/'+ str(congress) +'/house/members.json')
    senateList, houseList = [],[]
    if senate_members['status'] == 'OK':
        senateList = [(senator['id'], senator['first_name'] + ' ' + senator['last_name'] + '(' + senator['party'] + ')') for senator in senate_members['results'][0]['members']]
    if house_members['status'] == 'OK':
        houseList = [(rep['id'],rep['first_name'] + ' ' + rep['last_name'] + '(' + rep['party'] + ')') for rep in house_members['results'][0]['members']]
    return dict(senateList + houseList)
    
    
def buildGraph(members, congress):
    graph = {}
    for m in members:
        graph[m] = []
    
    for i in range(1, MOST_RECENT_HR_BILL+1):
        print("At HR{0}".format(i))
        edge = getSponsors("hr{0}".format(i), congress)
        if edge: # not (,)
            graph[edge[0]].extend(edge[1])
    
    for i in range(1, MOST_RECENT_S_BILL+1):
        print("At S{0}".format(i))
        edge = getSponsors("s{0}".format(i), congress)
        if edge: # not (,)
            graph[edge[0]].extend(edge[1])
        
    return graph

def buildFilteredGraph(members, congress):
    graph = {}
    for m in members:
        graph[m] = []
    
    for i in sorted(list(hr_passed_one_house)):
        print("At HR{0}".format(i))
        edge = getSponsors("hr{0}".format(i), congress)
        if edge: # not (,)
            graph[edge[0]].extend(edge[1])
    
    for i in sorted(list(senate_passed_one_house)):
        print("At S{0}".format(i))
        edge = getSponsors("s{0}".format(i), congress)
        if edge: # not (,)
            graph[edge[0]].extend(edge[1])
        
    return graph

def reverseCurrentGraph(curr_graph):
    new_graph = {}
    for m in curr_graph:
        new_graph[m] = []
    for m in curr_graph:
        cosponsored = curr_graph[m]
        for c in cosponsored:
            new_graph[c].append(m)
    return new_graph


def ranker(members, graph, p=.15, iterations=1000000):
    assert len(graph) == len(members)
    member_list = list(graph.keys())
    current = random.choice(member_list)
    members[current] += 1
    for i in range(iterations):
#         if i % 10 == 0:
#             print("Iteration: {0}".format(i))
        if len(graph[current]) == 0 or random.random() < p:
            current = random.choice(member_list)
#             print("reset")

        else:
            neighbors = graph[current]
            current = neighbors[random.randint(0, len(neighbors)-1)]
#             print("Continue")
        members[current] += 1
    return members


def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
# members = getMembers(CONGRESS)
# graph = buildGraph(members, CONGRESS)
# names = getNameIDPairing(CONGRESS)
# filteredGraph = buildFilteredGraph(members, CONGRESS)

# save_obj(filteredGraph, 'congress' + str(CONGRESS) + '_filteredGraphAtLeastOneHouse')
# save_obj(members, 'congress' + str(CONGRESS) + '_members')
# save_obj(graph, 'congress' + str(CONGRESS) + '_graph')
# save_obj(names, 'congress' + str(CONGRESS) + '_names')
# Out:
# At HR2
# At HR3
# At HR5
# At HR6
# At HR7
# At HR8
# At HR10
# At HR22
# At HR23
# At HR26
# At HR30
# At HR33
# At HR34
# At HR35
# At HR36
# At HR37
# At HR50
# At HR87
# At HR91
# At HR136
# At HR158
# At HR159
# At HR160
# At HR161
# At HR172
# At HR181
# At HR185
# At HR203
# At HR208
# At HR212
# At HR216
# At HR223
# At HR233
# At HR235
# At HR237
# At HR240
# At HR246
# At HR251
# At HR280
# At HR284
# At HR285
# At HR294
# At HR295
# At HR299
# At HR313
# At HR322
# At HR323
# At HR324
# At HR329
# At HR336
# At HR348
# At HR350
# At HR351
# At HR357
# At HR360
# At HR361
# At HR373
# At HR387
# At HR398
# At HR400
# At HR404
# At HR427
# At HR431
# At HR432
# At HR433
# At HR455
# At HR460
# At HR468
# At HR469
# At HR471
# At HR474
# At HR5985
# At HR5995
# At HR6004
# At HR6007
# At HR6009
# At HR6014
# At HR6076
# At HR6094
# At HR6130
# At HR6135
# At HR6138
# At HR6186
# At HR6282
# At HR6297
# At HR6302
# At HR6303
# At HR6304
# At HR6323
# At HR6375
# At HR6392
# At HR6393
# At HR6394
# At HR6400
# At HR6401
# At HR6415
# At HR6416
# At HR6427
# At HR6431
# At HR6435
# At HR6438
# At HR6450
# At HR6451
# At HR6452
# At HR6477
# At HR6480
# At S1
# At S8
# At S10
# At S32
# At S125
# At S136
# At S139
# At S142
# At S143
# At S178
# At S179
# At S184
# At S192
# At S209
# At S227
# At S230
# At S238
# At S242
# At S246
# At S253
# At S261
# At S267
# At S284
# At S286
# At S290
# At S295
# At S301
# At S304
# At S337
# At S349
# At S434
# At S461
# At S483
# At S501
# At S524
# At S527
# At S535
# At S546
# At S565
# At S571
# At S599
# At S607
# At S611
# At S612
# At S614
# At S653
# At S665
# At S719
# At S754
# At S756
# At S764
# At S795
# At S799
# At S802
# At S808
# At S817
# At S818
# At S971
# At S984
# At S986
# At S993
# At S994
# At S1004
# At S1090
# At S1109
# At S1115
# At S1124
# At S1168
# At S1170
# At S1172
# At S1177
# At S1180
# At S1203
# At S1252
# At S1297
# At S1300
# At S1335
# At S1347
# At S1352
# At S1356
# At S1359
# At S1362
# At S1402
# At S1436
# At S1443
# At S1461
# At S1463
# At S1479
# At S1482
# At S1492
# At S1493
# At S1523
# At S1550
# At S1555
# At S1568
# At S1576
# At S1579
# At S1580
# At S1596
# At S1599
# At S1603
# At S1616
# At S1629
# At S1632
# At S1635
# At S1638
# At S1698
# At S1707
# At S1719
# At S1731
# At S1776
# At S1808
# At S1826
# At S1831
# At S1875
# At S1878
# At S1886
# At S1890
# At S1893
# At S1915
# At S1935
# At S2012
# At S2032
# At S2036
# At S2040
# At S2044
# At S2058
# At S2078
# At S2082
# At S2109
# At S2133
# At S2143
# At S2152
# At S2162
# At S2234
# At S2261
# At S2276
# At S2280
# At S2306
# At S2308
# At S2325
# At S2328
# At S2340
# At S2348
# At S2360
# At S2393
# At S2422
# At S2425
# At S2426
# At S2451
# At S2465
# At S2487
# At S2512
# At S2577
# At S2613
# At S2614
# At S2650
# At S2683
# At S2736
# At S2754
# At S2755
# At S2781
# At S2808
# At S2815
# At S2829
# At S2840
# At S2845
# At S2848
# At S2852
# At S2854
# At S2873
# At S2891
# At S2893
# At S2943
# At S2944
# At S2959
# At S2971
# At S2974
# At S3021
# At S3028
# At S3055
# At S3076
# At S3084
# At S3086
# At S3112
# At S3183
# At S3207
# At S3282
# At S3283
# At S3336
# At S3346
# At S3386
# At S3395
# At S3438
# At S3492

# %%
filteredGraph = load_obj('congress' + str(CONGRESS) + '_filteredGraph')
graph = load_obj('congress' + str(CONGRESS) + '_graph')
graph = reverseCurrentGraph(filteredGraph)
members = load_obj('congress' + str(CONGRESS) + '_members')
names = load_obj('congress' + str(CONGRESS) + '_names')

# %%
members = load_obj('congress' + str(CONGRESS) + '_members')
ranking = ranker(members, graph,.15, 100000)
member_ranks = [pair[0] for pair in sorted(members.items(), key = lambda item: item[1], reverse=True)]
top_score = members[member_ranks[0]]
for i in range(len(member_ranks)):
    print("%d %f: %s" % (i+1,members[member_ranks[i]]/top_score, names[member_ranks[i]]))
# Out:
# 1 1.000000: Brett Guthrie(R)
# 2 0.619414: Erik Paulsen(R)
# 3 0.611722: Michael McCaul(R)
# 4 0.592308: Todd Young(R)
# 5 0.576190: Orrin Hatch(R)
# 6 0.527473: Christopher Smith(R)
# 7 0.487546: Susan Brooks(R)
# 8 0.486447: Kevin Brady(R)
# 9 0.480952: Sam Johnson(R)
# 10 0.476190: Bill Posey(R)
# 11 0.474725: Trent Franks(R)
# 12 0.470696: Pete Olson(R)
# 13 0.461172: John Cornyn(R)
# 14 0.435165: Edward Royce(R)
# 15 0.434066: Martha McSally(R)
# 16 0.414286: Kevin Yoder(R)
# 17 0.412088: Jeff Fortenberry(R)
# 18 0.407692: Rodney Davis(R)
# 19 0.392308: Terri Sewell(D)
# 20 0.378022: Carolyn Maloney(D)
# 21 0.377289: Phil Roe(R)
# 22 0.370330: Robert Goodlatte(R)
# 23 0.347985: Seth Moulton(D)
# 24 0.341392: Adam Kinzinger(R)
# 25 0.335165: John Hoeven(R)
# 26 0.324542: Mike Bishop(R)
# 27 0.320879: Tim Murphy(R)
# 28 0.318315: Roy Blunt(R)
# 29 0.315751: James Inhofe(R)
# 30 0.312088: Jeff Sessions(R)
# 31 0.310623: Diane Black(R)
# 32 0.304029: Fred Upton(R)
# 33 0.301099: Deb Fischer(R)
# 34 0.289744: Mike Pompeo(R)
# 35 0.260806: Pat Meehan(R)
# 36 0.258974: John Ratcliffe(R)
# 37 0.252747: Dianne Feinstein(D)
# 38 0.252015: Bill Shuster(R)
# 39 0.234066: Eliot Engel(D)
# 40 0.228205: Benjamin Cardin(D)
# 41 0.227473: Mazie Hirono(D)
# 42 0.217949: Blaine Luetkemeyer(R)
# 43 0.217216: Joe Barton(R)
# 44 0.215385: Tom McClintock(R)
# 45 0.214652: Jeff Miller(R)
# 46 0.210623: Jackie Walorski(R)
# 47 0.205495: Tom Price(R)
# 48 0.204762: Vern Buchanan(R)
# 49 0.199634: Lynn Jenkins(R)
# 50 0.194872: Ted Yoho(R)
# 51 0.187546: Tim Walz(D)
# 52 0.186813: Frank Guinta(R)
# 53 0.180952: Lamar Smith(R)
# 54 0.180586: Mark Amodei(R)
# 55 0.175824: Cathy McMorris Rodgers(R)
# 56 0.175824: Kristi Noem(R)
# 57 0.172894: Lamar Alexander(R)
# 58 0.171062: Ann Wagner(R)
# 59 0.171062: Richard Hudson(R)
# 60 0.166300: Tim Walberg(R)
# 61 0.165201: Sheldon Whitehouse(D)
# 62 0.165201: Charles Grassley(R)
# 63 0.161905: Katherine Clark(D)
# 64 0.160806: Darrell Issa(R)
# 65 0.159707: Grace Meng(D)
# 66 0.153846: Al Franken(D)
# 67 0.153114: Stephen Fincher(R)
# 68 0.152747: Matt Salmon(R)
# 69 0.152381: Bradley Byrne(R)
# 70 0.150183: Glenn Thompson(R)
# 71 0.145055: Tom MacArthur(R)
# 72 0.142857: Edward Whitfield(R)
# 73 0.142125: Michael Burgess(R)
# 74 0.141758: Ted Poe(R)
# 75 0.138828: Henry Cuellar(D)
# 76 0.138462: Heidi Heitkamp(D)
# 77 0.136630: Cory Gardner(R)
# 78 0.135897: Joseph Kennedy III(D)
# 79 0.131868: Pat Tiberi(R)
# 80 0.128205: Candice Miller(R)
# 81 0.127106: Patrick Toomey(R)
# 82 0.124176: Roger Wicker(R)
# 83 0.123077: Patrick Leahy(D)
# 84 0.121978: John Katko(R)
# 85 0.120879: K. Conaway(R)
# 86 0.116117: David Valadao(R)
# 87 0.115751: Jim Renacci(R)
# 88 0.113553: Lois Capps(D)
# 89 0.111355: Gus Bilirakis(R)
# 90 0.107692: Steve Stivers(R)
# 91 0.106960: Lee Zeldin(R)
# 92 0.106960: Cynthia Lummis(R)
# 93 0.106593: Bill Huizenga(R)
# 94 0.106593: Todd Rokita(R)
# 95 0.105128: Tom Marino(R)
# 96 0.105128: Steve Russell(R)
# 97 0.103663: Stephen Lynch(D)
# 98 0.103297: Susan Collins(R)
# 99 0.103297: Dennis Ross(R)
# 100 0.102930: Charles Boustany Jr.(R)
# 101 0.102198: Will Hurd(R)
# 102 0.099634: David Rouzer(R)
# 103 0.099634: Stacey Plaskett(D)
# 104 0.097802: Bob Casey(D)
# 105 0.097802: Lou Barletta(R)
# 106 0.097436: Kenny Marchant(R)
# 107 0.095238: Richard Burr(R)
# 108 0.095238: Mitch McConnell(R)
# 109 0.094505: Bob Corker(R)
# 110 0.092674: Peter King(R)
# 111 0.091575: Robert Latta(R)
# 112 0.089744: Karen Bass(D)
# 113 0.089011: Andy Barr(R)
# 114 0.088645: Joe Heck(R)
# 115 0.087179: F. Sensenbrenner(R)
# 116 0.087179: Bill Johnson(R)
# 117 0.086447: David McKinley(R)
# 118 0.085348: Rob Portman(R)
# 119 0.082418: Peter Roskam(R)
# 120 0.081319: Duncan Hunter(R)
# 121 0.080586: Barry Loudermilk(R)
# 122 0.080586: Kelly Ayotte(R)
# 123 0.080220: John Barrasso(R)
# 124 0.078755: Johnny Isakson(R)
# 125 0.078755: Carlos Curbelo(R)
# 126 0.078022: Dan Kildee(D)
# 127 0.076923: Matt Cartwright(D)
# 128 0.075824: Steven Chabot(R)
# 129 0.073626: José Serrano(D)
# 130 0.073260: Joseph Crowley(D)
# 131 0.072527: Sean Duffy(R)
# 132 0.072161: Bill Nelson(D)
# 133 0.071062: Jerry Moran(R)
# 134 0.070696: Ron Wyden(D)
# 135 0.070330: Daniel Donovan(R)
# 136 0.069231: John Lewis(D)
# 137 0.068498: Donald Beyer(D)
# 138 0.068498: Mark Walker(R)
# 139 0.068498: Jason Smith(R)
# 140 0.065568: Ron Johnson(R)
# 141 0.065568: Julia Brownley(D)
# 142 0.064469: David Young(R)
# 143 0.063736: Susan Davis(D)
# 144 0.063004: Steve Knight(R)
# 145 0.062637: Charlie Dent(R)
# 146 0.061905: Barbara Boxer(D)
# 147 0.060440: Madeleine Bordallo(D)
# 148 0.060073: Thomas Carper(D)
# 149 0.059707: Jeff Flake(R)
# 150 0.058974: Dave Joyce(R)
# 151 0.058974: Elise Stefanik(R)
# 152 0.058608: Alex Mooney(R)
# 153 0.057875: Jerry McNerney(D)
# 154 0.057875: Kevin McCarthy(R)
# 155 0.057509: Kevin Cramer(R)
# 156 0.057509: Ileana Ros-Lehtinen(R)
# 157 0.057143: Robert Wittman(R)
# 158 0.056777: Luke Messer(R)
# 159 0.056410: John Shimkus(R)
# 160 0.054945: Marsha Blackburn(R)
# 161 0.054579: Louie Gohmert(R)
# 162 0.054212: Nita Lowey(D)
# 163 0.054212: Mark Kirk(R)
# 164 0.054212: Robert Scott(D)
# 165 0.052747: Judy Chu(D)
# 166 0.052747: Roger Williams(R)
# 167 0.052381: Randy Weber(R)
# 168 0.051648: James Clyburn(D)
# 169 0.051648: John Thune(R)
# 170 0.051282: Robert Dold(R)
# 171 0.051282: Brian Schatz(D)
# 172 0.051282: Alan Lowenthal(D)
# 173 0.051282: Frank Pallone(D)
# 174 0.050549: Michael Fitzpatrick(R)
# 175 0.050183: Raúl Grijalva(D)
# 176 0.050183: Tom Emmer(R)
# 177 0.049451: Sheila Jackson-Lee(D)
# 178 0.049451: Chris Gibson(R)
# 179 0.049084: Ted Cruz(R)
# 180 0.048352: Mimi Walters(R)
# 181 0.047985: Buddy Carter(R)
# 182 0.046886: Donald Payne Jr.(D)
# 183 0.046520: Jon Tester(D)
# 184 0.045421: Randy Hultgren(R)
# 185 0.045421: Dave Trott(R)
# 186 0.043956: Kyrsten Sinema(D)
# 187 0.043590: Dean Heller(R)
# 188 0.043590: Louise Slaughter(D)
# 189 0.042857: John Kline(R)
# 190 0.041758: Chuck Fleischmann(R)
# 191 0.041026: Frank LoBiondo(R)
# 192 0.040659: Bill Foster(D)
# 193 0.040293: Chris Collins(R)
# 194 0.039560: Mike Kelly(R)
# 195 0.039194: Doug Collins(R)
# 196 0.039194: Albio Sires(D)
# 197 0.039194: Alma Adams(D)
# 198 0.038828: Renee Ellmers(R)
# 199 0.038462: Bill Keating(D)
# 200 0.038095: Dan Newhouse(R)
# 201 0.036996: Mike Bost(R)
# 202 0.036630: William Clay(D)
# 203 0.036630: Jason Chaffetz(R)
# 204 0.036630: Marco Rubio(R)
# 205 0.035897: John Moolenaar(R)
# 206 0.035531: Brad Ashford(D)
# 207 0.035165: Charles Schumer(D)
# 208 0.034799: Thom Tillis(R)
# 209 0.034432: Ben Luján(D)
# 210 0.034432: Leonard Lance(R)
# 211 0.033700: Peter Visclosky(D)
# 212 0.033700: David Brat(R)
# 213 0.033333: Brenda Lawrence(D)
# 214 0.032967: William Thornberry(R)
# 215 0.032967: Joaquín Castro(D)
# 216 0.032234: Robert Pittenger(R)
# 217 0.031502: Barbara Comstock(R)
# 218 0.031136: Mike Quigley(D)
# 219 0.030403: Joyce Beatty(D)
# 220 0.030403: David Cicilline(D)
# 221 0.030403: Greg Walden(R)
# 222 0.030403: Evan Jenkins(R)
# 223 0.030037: Paul Gosar(R)
# 224 0.029670: Jan Schakowsky(D)
# 225 0.029304: Virginia Foxx(R)
# 226 0.029304: Juan Vargas(D)
# 227 0.028938: Tom Reed(R)
# 228 0.028938: Patty Murray(D)
# 229 0.028571: Sean Maloney(D)
# 230 0.028571: Donald Norcross(D)
# 231 0.027839: Robert Menendez(D)
# 232 0.027839: Amy Klobuchar(D)
# 233 0.027839: Jeffrey Denham(R)
# 234 0.027473: Frank Lucas(R)
# 235 0.027473: Bruce Westerman(R)
# 236 0.027473: Dan Sullivan(R)
# 237 0.027106: David Scott(D)
# 238 0.026374: Brad Wenstrup(R)
# 239 0.026374: Richard Hanna(R)
# 240 0.026007: G. Butterfield(D)
# 241 0.025641: Ruben Gallego(D)
# 242 0.025275: Cory Booker(D)
# 243 0.024908: Paul Ryan(R)
# 244 0.024542: Al Green(D)
# 245 0.024176: John Carney(D)
# 246 0.024176: Lloyd Doggett(D)
# 247 0.024176: Joni Ernst(R)
# 248 0.024176: Jody Hice(R)
# 249 0.023810: Kathleen Rice(D)
# 250 0.023810: Keith Rothfus(R)
# 251 0.023077: Cedric Richmond(D)
# 252 0.023077: Scott Perry(R)
# 253 0.022711: Ann Kuster(D)
# 254 0.022711: Hank Johnson(D)
# 255 0.022711: Denny Heck(D)
# 256 0.022711: Tammy Baldwin(D)
# 257 0.022344: Tim Scott(R)
# 258 0.022344: Devin Nunes(R)
# 259 0.021978: Chellie Pingree(D)
# 260 0.021978: Brian Babin(R)
# 261 0.021245: Scott Tipton(R)
# 262 0.021245: John Sarbanes(D)
# 263 0.020879: Blake Farenthold(R)
# 264 0.020879: Adrian Smith(R)
# 265 0.020513: David Vitter(R)
# 266 0.020513: Scott Garrett(R)
# 267 0.020513: James Lankford(R)
# 268 0.020147: Hakeem Jeffries(D)
# 269 0.019780: Anna Eshoo(D)
# 270 0.019048: Paul Cook(R)
# 271 0.019048: Jackie Speier(D)
# 272 0.018681: Nydia Velázquez(D)
# 273 0.018681: Ken Calvert(R)
# 274 0.017949: Mark DeSaulnier(D)
# 275 0.017949: Mia Love(R)
# 276 0.017949: Grace Napolitano(D)
# 277 0.017949: Ed Perlmutter(D)
# 278 0.017949: Elizabeth Esty(D)
# 279 0.017582: Larry Bucshon(R)
# 280 0.017582: André Carson(D)
# 281 0.017582: Steve Pearce(R)
# 282 0.017216: Raul Ruiz(D)
# 283 0.017216: Bonnie Watson Coleman(D)
# 284 0.016850: Frederica Wilson(D)
# 285 0.016850: Ryan Costello(R)
# 286 0.016850: John McCain(R)
# 287 0.016484: Darin LaHood(R)
# 288 0.016484: Cresent Hardy(R)
# 289 0.016484: Don Young(R)
# 290 0.016117: Garret Graves(R)
# 291 0.015751: Elijah Cummings(D)
# 292 0.015751: Luis Gutiérrez(D)
# 293 0.015385: Mike Doyle(D)
# 294 0.015385: Bruce Poliquin(R)
# 295 0.015385: Rod Blum(R)
# 296 0.015385: Richard Neal(D)
# 297 0.015385: Jared Polis(D)
# 298 0.015385: Corrine Brown(D)
# 299 0.015018: Mike Simpson(R)
# 300 0.015018: Dana Rohrabacher(R)
# 301 0.015018: Steve Scalise(R)
# 302 0.015018: Tammy Duckworth(D)
# 303 0.015018: Randy Neugebauer(R)
# 304 0.015018: Jim Risch(R)
# 305 0.014652: John Boozman(R)
# 306 0.014652: Bill Cassidy(R)
# 307 0.014286: Steve Womack(R)
# 308 0.014286: Gwen Moore(D)
# 309 0.014286: Christopher Murphy(D)
# 310 0.014286: Tom Cotton(R)
# 311 0.014286: Gerald Connolly(D)
# 312 0.014286: David Perdue(R)
# 313 0.014286: Harold Rogers(R)
# 314 0.013919: Mark Sanford(R)
# 315 0.013919: Sam Farr(D)
# 316 0.013919: John Boehner(R)
# 317 0.013919: Mark Takano(D)
# 318 0.013919: Joe Pitts(R)
# 319 0.013553: Scott Peters(D)
# 320 0.013553: Suzanne Bonamici(D)
# 321 0.013553: Jaime Herrera Beutler(R)
# 322 0.013553: John Conyers Jr.(D)
# 323 0.013553: Rick Crawford(R)
# 324 0.013553: Ander Crenshaw(R)
# 325 0.013187: Lisa Murkowski(R)
# 326 0.013187: Claire McCaskill(D)
# 327 0.013187: Chris Van Hollen(D)
# 328 0.013187: Mike Lee(R)
# 329 0.013187: John Delaney(D)
# 330 0.013187: Elizabeth Warren(D)
# 331 0.013187: Tim Ryan(D)
# 332 0.013187: Doug Lamborn(R)
# 333 0.012821: Cheri Bustos(D)
# 334 0.012821: Rosa DeLauro(D)
# 335 0.012821: Pete Aguilar(D)
# 336 0.012454: David Jolly(R)
# 337 0.012454: Ben Sasse(R)
# 338 0.012454: Mo Brooks(R)
# 339 0.012454: Glenn Grothman(R)
# 340 0.012454: Amata Radewagen(R)
# 341 0.012454: Rick Larsen(D)
# 342 0.012454: Linda Sánchez(D)
# 343 0.012454: Barbara Lee(D)
# 344 0.012454: Collin Peterson(D)
# 345 0.012454: Chris Stewart(R)
# 346 0.012454: Joe Donnelly(D)
# 347 0.012454: Emanuel Cleaver II(D)
# 348 0.012088: John Carter(R)
# 349 0.012088: Michael Turner(R)
# 350 0.012088: Richard Blumenthal(D)
# 351 0.012088: Gregorio &#39;Kilili&#39; Sablan(I)
# 352 0.012088: Gary Peters(D)
# 353 0.012088: Tom Rice(R)
# 354 0.012088: Aaron Schock(R)
# 355 0.012088: Tim Kaine(D)
# 356 0.012088: Marcia Fudge(D)
# 357 0.012088: Lucille Roybal-Allard(D)
# 358 0.012088: Trent Kelly(R)
# 359 0.011722: Ken Buck(R)
# 360 0.011722: Debbie Wasserman Schultz(D)
# 361 0.011722: Mike Grimm(R)
# 362 0.011722: Jeff Merkley(D)
# 363 0.011722: Curt Clawson(R)
# 364 0.011722: Steve Israel(D)
# 365 0.011722: Markwayne Mullin(R)
# 366 0.011722: Michael Bennet(D)
# 367 0.011722: John Culberson(R)
# 368 0.011722: Daniel Lipinski(D)
# 369 0.011355: Tom Udall(D)
# 370 0.011355: Chaka Fattah(D)
# 447 0.009524: Jeb Hensarling(R)
# 448 0.009524: Gary Palmer(R)
# 449 0.009524: Mark Meadows(R)
# 450 0.009524: Eddie Johnson(D)
# 451 0.009524: Rob Bishop(R)
# 452 0.009524: Jeanne Shaheen(D)
# 453 0.009524: Ron DeSantis(R)
# 454 0.009524: Gregory Meeks(D)
# 455 0.009524: Tulsi Gabbard(D)
# 456 0.009524: Angus King(I)
# 457 0.009524: Kathy Castor(D)
# 458 0.009524: Mike Thompson(D)
# 459 0.009524: Justin Amash(R)
# 460 0.009524: Michael Honda(D)
# 461 0.009524: Derek Kilmer(D)
# 462 0.009524: Walter Jones(R)
# 463 0.009524: Michelle Lujan Grisham(D)
# 464 0.009524: Pat Roberts(R)
# 465 0.009524: Marc Veasey(D)
# 466 0.009158: Mark Takai(D)
# 467 0.009158: Danny Davis(D)
# 468 0.009158: Dave Loebsack(D)
# 469 0.009158: Beto O&#39;Rourke(D)
# 470 0.009158: Dave Reichert(R)
# 471 0.009158: Rand Paul(R)
# 472 0.009158: Lois Frankel(D)
# 473 0.009158: Janice Hahn(D)
# 474 0.009158: Edward Markey(D)
# 475 0.009158: Scott DesJarlais(R)
# 476 0.009158: Raúl Labrador(R)
# 477 0.009158: Robert Brady(D)
# 478 0.009158: Pete Sessions(R)
# 479 0.009158: Norma Torres(D)
# 480 0.008791: Vicky Hartzler(R)
# 481 0.008791: John Duncan Jr.(R)
# 482 0.008791: Bill Pascrell Jr.(D)
# 483 0.008791: Barbara Mikulski(D)
# 484 0.008791: George Holding(R)
# 485 0.008791: Gene Green(D)
# 486 0.008791: Kirsten Gillibrand(D)
# 487 0.008791: Robert Hurt(R)
# 488 0.008791: Mario Diaz-Balart(R)
# 489 0.008791: Bob Gibbs(R)
# 490 0.008791: Ron Kind(D)
# 491 0.008791: Bill Flores(R)
# 492 0.008791: Donna Edwards(D)
# 493 0.008791: Jim McGovern(D)
# 494 0.008791: Adam Smith(D)
# 495 0.008425: Thad Cochran(R)
# 496 0.008425: Dina Titus(D)
# 497 0.008425: Sherrod Brown(D)
# 498 0.008425: Debbie Dingell(D)
# 499 0.008425: Niki Tsongas(D)
# 500 0.008425: Jeffrey Duncan(R)
# 501 0.008425: Andy Harris(R)
# 502 0.008425: Dwight Evans(D)
# 503 0.008425: Yvette Clarke(D)
# 504 0.008425: Shelley Capito(R)
# 505 0.008425: Lynn Westmoreland(R)
# 506 0.008425: Michael Capuano(D)
# 507 0.008425: Mark Warner(D)
# 508 0.008425: Rubén Hinojosa(D)
# 509 0.008425: Colleen Hanabusa(D)
# 510 0.008059: Reid Ribble(R)
# 511 0.008059: Jim Cooper(D)
# 512 0.008059: Bernard Sanders(I)
# 513 0.008059: J. Forbes(R)
# 514 0.008059: Kurt Schrader(D)
# 515 0.008059: Michael Enzi(R)
# 516 0.008059: Morgan Griffith(R)
# 517 0.008059: Jared Huffman(D)
# 518 0.008059: Joe Wilson(R)
# 519 0.007692: Mike Rogers(R)
# 520 0.007692: Bennie Thompson(D)
# 521 0.007692: James Comer(R)
# 522 0.007692: Tom Cole(R)
# 523 0.007692: Jim Costa(D)
# 524 0.007692: Eric Swalwell(D)
# 525 0.007692: Robin Kelly(D)
# 526 0.007692: Thomas Massie(R)
# 527 0.007692: Brian Higgins(D)
# 528 0.007692: Daniel Coats(R)
# 529 0.007326: Mark Pocan(D)
# 530 0.007326: Steve King(R)
# 531 0.007326: Alan Grayson(D)
# 532 0.007326: Peter DeFazio(D)
# 533 0.007326: Loretta Sánchez(D)
# 534 0.006960: Charles Rangel(D)
# 535 0.006960: Joe Courtney(D)
# 536 0.006960: Warren Davidson(R)
# 537 0.006960: Patrick McHenry(R)
# 538 0.006593: Keith Ellison(D)
# 539 0.006593: Doris Matsui(D)
# 540 0.006593: Trey Gowdy(R)
# 541 0.006593: Zoe Lofgren(D)
# 542 0.006593: Mike Rounds(R)
# 543 0.006227: Austin Scott(R)
# 544 0.006227: Marcy Kaptur(D)
# 545 0.005861: John Mica(R)
# 546 0.005861: Sanford Bishop Jr.(D)
# 547 0.005495: Martha Roby(R)
# 548 0.005495: C.A. Dutch Ruppersberger(D)

# %%
test = getJSON('https://api.propublica.org/congress/v1/members/N000147/bills/introduced.json')

# %%
test2 = getJSON('https://api.propublica.org/congress/v1/114/bills/hr6477/cosponsors.json')

# %%
test3 = getJSON('https://api.propublica.org/congress/v1/114/bills/hr6431/cosponsors.json')

# %%
test3 = getJSON('https://api.propublica.org/congress/v1/114/bills/hr6431/cosponsors.json')
test3['results'][0]['latest_major_action'][:17] == 'Became Public Law'
# Out:
# True

# %%
test4 = load_obj('congress' + str(CONGRESS) + '_filteredGraph')

# %%
len(load_obj('congress114_members'))
# Out:
# 548

# %%
getJSON('https://api.propublica.org/congress/v1/'+ str(114) +'/house/members.json')['results'][0]['members'][0]

# print(propub)
# Out:
# {'api_uri': 'https://api.propublica.org/congress/v1/members/A000055.json',
#  'crp_id': '',
#  'cspan_id': '45516',
#  'district': '4',
#  'domain': 'aderholt.house.gov',
#  'dw_nominate': '',
#  'facebook_account': 'RobertAderholt',
#  'first_name': 'Robert',
#  'google_entity_id': '/m/024p03',
#  'govtrack_id': '400004',
#  'icpsr_id': '29701',
#  'id': 'A000055',
#  'ideal_point': '',
#  'in_office': 'false',
#  'last_name': 'Aderholt',
#  'leadership_role': '',
#  'middle_name': 'B.',
#  'missed_votes': '22',
#  'missed_votes_pct': '1.66',
#  'next_election': '2016',
#  'ocd_id': 'ocd-division/country:us/state:al/cd:4',
#  'office': '',
#  'party': 'R',
#  'phone': '',
#  'rss_url': 'https://aderholt.house.gov/rss.xml',
#  'seniority': '20',
#  'state': 'AL',
#  'total_present': '0',
#  'total_votes': '1325',
#  'twitter_account': 'Robert_Aderholt',
#  'url': 'https://aderholt.house.gov',
#  'votes_with_party_pct': '94.40',
#  'votesmart_id': ''}

# %%
# # print(propub)
# print(len(propub))
# propub[0]['govtrack_id']

for i in range(1, 448):
    govtrack = propub[i]['govtrack_id']
    requests.get('https://www.govtrack.us/api/v2/person/' + str(govtrack)).json()
